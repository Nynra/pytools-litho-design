# %%
from pytools_litho_design.devices.htron import planar_hTron
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
htron = planar_hTron(
    wire_width=0.5,
    channel_width=0.1,
    channel_length=5,
    gate_width=0.02,
    gap=0.1,
)
htron.plot()
plt.show()
