# %% [markdown]
# # Schematic
#
# A schematic is a graph representation of your circuit.
#
# For complex circuits, a schematic allows you to create symbols and hierarchy levels to represent your circuit.
#
# Having a schematic allows you to also ensure that your layout matches you schematic (design intent).
#
# There are many schematic capture tools out there:
#
# - Qucs-s: for RF.
# - Xschem: for analog circuits.
# - Lumerical interconnect: for photonic circuits.
#
# These tools allow you to both create schematics with your mouse or by code.
#
# gdsfactory also allows you to create complex Schematics directly from python with a very simple interface.

# %%
import gdsfactory as gf
import gdsfactory.schematic as gt

# %% [markdown]
# Lets create a MZI lattice of 3 elements.

# %%
s = gt.Schematic()
s.add_instance("mzi1", gt.Instance(component=gf.c.mzi(delta_length=10)))
s.add_instance("mzi2", gt.Instance(component=gf.c.mzi(delta_length=100)))
s.add_instance("mzi3", gt.Instance(component=gf.c.mzi(delta_length=200)))
s.add_placement("mzi1", gt.Placement(x=000, y=0))
s.add_placement("mzi2", gt.Placement(x=100, y=100))
s.add_placement("mzi3", gt.Placement(x=200, y=0))
s.add_net(gt.Net(p1="mzi1,o2", p2="mzi2,o2"))
s.add_net(gt.Net(p1="mzi2,o2", p2="mzi3,o1"))
g = s.netlist
g
# Out:
# Netlist(pdk='', instances={'mzi1': Instance(component='mzi', settings={'delta_length': 10, 'length_y': 2.0, 'length_x': 0.1, 'bend': 'bend_euler', 'straight': 'straight', 'splitter': 'mmi1x2', 'with_splitter': True, 'port_e1_splitter': 'o2', 'port_e0_splitter': 'o3', 'port_e1_combiner': 'o2', 'port_e0_combiner': 'o3', 'port1': 'o1', 'port2': 'o2', 'nbends': 2, 'cross_section': 'strip', 'mirror_bot': False, 'add_optical_ports_arms': False, 'min_length': 0.01, 'auto_rename_ports': True}, info={}, array=None), 'mzi2': Instance(component='mzi', settings={'delta_length': 100, 'length_y': 2.0, 'length_x': 0.1, 'bend': 'bend_euler', 'straight': 'straight', 'splitter': 'mmi1x2', 'with_splitter': True, 'port_e1_splitter': 'o2', 'port_e0_splitter': 'o3', 'port_e1_combiner': 'o2', 'port_e0_combiner': 'o3', 'port1': 'o1', 'port2': 'o2', 'nbends': 2, 'cross_section': 'strip', 'mirror_bot': False, 'add_optical_ports_arms': False, 'min_length': 0.01, 'auto_rename_ports': True}, info={}, array=None), 'mzi3': Instance(component='mzi', settings={'delta_length': 200, 'length_y': 2.0, 'length_x': 0.1, 'bend': 'bend_euler', 'straight': 'straight', 'splitter': 'mmi1x2', 'with_splitter': True, 'port_e1_splitter': 'o2', 'port_e0_splitter': 'o3', 'port_e1_combiner': 'o2', 'port_e0_combiner': 'o3', 'port1': 'o1', 'port2': 'o2', 'nbends': 2, 'cross_section': 'strip', 'mirror_bot': False, 'add_optical_ports_arms': False, 'min_length': 0.01, 'auto_rename_ports': True}, info={}, array=None)}, placements={'mzi1': Placement(x=0.0, y=0.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False), 'mzi2': Placement(x=100.0, y=100.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False), 'mzi3': Placement(x=200.0, y=0.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False)}, connections={}, routes={'route_8': Bundle(links={'mzi1,o2': 'mzi2,o2'}, settings={}, routing_strategy='route_bundle'), 'route_9': Bundle(links={'mzi2,o2': 'mzi3,o1'}, settings={}, routing_strategy='route_bundle')}, name=None, info={}, ports={}, settings={}, nets=[], warnings={})

# %% [markdown]
# You can also create a splitter tree.

# %%
s = gt.Schematic()
s.add_instance("s11", gt.Instance(component=gf.c.mmi1x2()))
s.add_instance("s21", gt.Instance(component=gf.c.mmi1x2()))
s.add_instance("s22", gt.Instance(component=gf.c.mmi1x2()))
s.add_placement("s11", gt.Placement(x=000, y=0))
s.add_placement("s21", gt.Placement(x=100, y=+50))
s.add_placement("s22", gt.Placement(x=100, y=-50))
s.add_net(gt.Net(p1="s11,o2", p2="s21,o1"))
s.add_net(gt.Net(p1="s11,o3", p2="s22,o1"))
g = s.netlist
g
# Out:
# Netlist(pdk='', instances={'s11': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's21': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's22': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None)}, placements={'s11': Placement(x=0.0, y=0.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False), 's21': Placement(x=100.0, y=50.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False), 's22': Placement(x=100.0, y=-50.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False)}, connections={}, routes={'route_12': Bundle(links={'s11,o2': 's21,o1'}, settings={}, routing_strategy='route_bundle'), 'route_13': Bundle(links={'s11,o3': 's22,o1'}, settings={}, routing_strategy='route_bundle')}, name=None, info={}, ports={}, settings={}, nets=[], warnings={})

# %% [markdown]
# The nice thing is that you can abstract it to have as many levels as you need.

# %%
splitter = gf.components.mmi1x2()
n = 3
dx = 100
dy = 100
s = gt.Schematic()

for col in range(n):
    rows = 2**col
    for row in range(rows):
        s.add_instance(f"s{col}{row}", gt.Instance(component=splitter))
        s.add_placement(
            f"s{col}{row}", gt.Placement(x=col * dx, y=(row - rows / 2) * dy)
        )
        if col < n - 1:
            s.add_net(gt.Net(p1=f"s{col}{row},o2", p2=f"s{col+1}{2*row},o1"))
            s.add_net(gt.Net(p1=f"s{col}{row},o3", p2=f"s{col+1}{2*row+1},o1"))


g = s.netlist
g
# Out:
# Netlist(pdk='', instances={'s00': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's10': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's11': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's20': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's21': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's22': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's23': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None)}, placements={'s00': Placement(x=0.0, y=-50.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False), 's10': Placement(x=100.0, y=-100.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False), 's11': Placement(x=100.0, y=0.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False), 's20': Placement(x=200.0, y=-200.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False), 's21': Placement(x=200.0, y=-100.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False), 's22': Placement(x=200.0, y=0.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False), 's23': Placement(x=200.0, y=100.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False)}, connections={}, routes={'route_20': Bundle(links={'s00,o2': 's10,o1'}, settings={}, routing_strategy='route_bundle'), 'route_21': Bundle(links={'s00,o3': 's11,o1'}, settings={}, routing_strategy='route_bundle'), 'route_22': Bundle(links={'s10,o2': 's20,o1'}, settings={}, routing_strategy='route_bundle'), 'route_23': Bundle(links={'s10,o3': 's21,o1'}, settings={}, routing_strategy='route_bundle'), 'route_24': Bundle(links={'s11,o2': 's22,o1'}, settings={}, routing_strategy='route_bundle'), 'route_25': Bundle(links={'s11,o3': 's23,o1'}, settings={}, routing_strategy='route_bundle')}, name=None, info={}, ports={}, settings={}, nets=[], warnings={})

# %%
splitter = gf.components.mmi1x2()
n = 5
dx = 100
dy = 100
s = gt.Schematic()

for col in range(n):
    rows = 2**col
    for row in range(rows):
        s.add_instance(f"s{col}{row}", gt.Instance(component=splitter))
        s.add_placement(
            f"s{col}{row}", gt.Placement(x=col * dx, y=(row - rows / 2) * dy)
        )
        if col < n - 1:
            s.add_net(gt.Net(p1=f"s{col}{row},o2", p2=f"s{col+1}{2*row},o1"))
            s.add_net(gt.Net(p1=f"s{col}{row},o3", p2=f"s{col+1}{2*row+1},o1"))


g = s.netlist
g
# Out:
# Netlist(pdk='', instances={'s00': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's10': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's11': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's20': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's21': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's22': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's23': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's30': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's31': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's32': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's33': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's34': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's35': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's36': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's37': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's40': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's41': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None), 's42': Insta ...

# %%
dict(s.netlist)
# Out:
# {'pdk': '',
#  'instances': {'s00': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's10': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's11': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's20': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's21': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's22': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's23': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's30': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's31': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's32': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's33': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's34': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's35': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's36': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's37': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's40': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's41': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's42': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's43': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's44': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's45': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's46': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's47': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's48': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's49': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's410': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's411': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's412': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's413': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's414': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None),
#   's415': Instance(component='mmi1x2', settings={'width_taper': 1.0, 'length_taper': 10.0, 'length_mmi': 5.5, 'width_mmi': 2.5, 'gap_mmi': 0.25, 'taper': 'taper', 'straight': 'straight', 'cross_section': 'strip'}, info={}, array=None)},
#  'placements': {'s00': Placement(x=0.0, y=-50.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's10': Placement(x=100.0, y=-100.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's11': Placement(x=100.0, y=0.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's20': Placement(x=200.0, y=-200.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's21': Placement(x=200.0, y=-100.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's22': Placement(x=200.0, y=0.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's23': Placement(x=200.0, y=100.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's30': Placement(x=300.0, y=-400.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's31': Placement(x=300.0, y=-300.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's32': Placement(x=300.0, y=-200.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's33': Placement(x=300.0, y=-100.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's34': Placement(x=300.0, y=0.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's35': Placement(x=300.0, y=100.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's36': Placement(x=300.0, y=200.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's37': Placement(x=300.0, y=300.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's40': Placement(x=400.0, y=-800.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's41': Placement(x=400.0, y=-700.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's42': Placement(x=400.0, y=-600.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's43': Placement(x=400.0, y=-500.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's44': Placement(x=400.0, y=-400.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's45': Placement(x=400.0, y=-300.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's46': Placement(x=400.0, y=-200.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's47': Placement(x=400.0, y=-100.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's48': Placement(x=400.0, y=0.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's49': Placement(x=400.0, y=100.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's410': Placement(x=400.0, y=200.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's411': Placement(x=400.0, y=300.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's412': Placement(x=400.0, y=400.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's413': Placement(x=400.0, y=500.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's414': Placement(x=400.0, y=600.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False),
#   's415': Placement(x=400.0, y=700.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False)},
#  'connections': {},
#  'routes': {'route_26': Bundle(links={'s00,o2': 's10,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_27': Bundle(links={'s00,o3': 's11,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_28': Bundle(links={'s10,o2': 's20,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_29': Bundle(links={'s10,o3': 's21,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_30': Bundle(links={'s11,o2': 's22,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_31': Bundle(links={'s11,o3': 's23,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_32': Bundle(links={'s20,o2': 's30,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_33': Bundle(links={'s20,o3': 's31,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_34': Bundle(links={'s21,o2': 's32,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_35': Bundle(links={'s21,o3': 's33,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_36': Bundle(links={'s22,o2': 's34,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_37': Bundle(links={'s22,o3': 's35,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_38': Bundle(links={'s23,o2': 's36,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_39': Bundle(links={'s23,o3': 's37,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_40': Bundle(links={'s30,o2': 's40,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_41': Bundle(links={'s30,o3': 's41,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_42': Bundle(links={'s31,o2': 's42,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_43': Bundle(links={'s31,o3': 's43,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_44': Bundle(links={'s32,o2': 's44,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_45': Bundle(links={'s32,o3': 's45,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_46': Bundle(links={'s33,o2': 's46,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_47': Bundle(links={'s33,o3': 's47,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_48': Bundle(links={'s34,o2': 's48,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_49': Bundle(links={'s34,o3': 's49,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_50': Bundle(links={'s35,o2': 's410,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_51': Bundle(links={'s35,o3': 's411,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_52': Bundle(links={'s36,o2': 's412,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_53': Bundle(links={'s36,o3': 's413,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_54': Bundle(links={'s37,o2': 's414,o1'}, settings={}, routing_strategy='route_bundle'),
#   'route_55': Bundle(links={'s37,o3': 's415,o1'}, settings={}, routing_strategy='route_bundle')},
#  'name': None,
#  'info': {},
#  'ports': {},
#  'settings': {},
#  'nets': [],
#  'warnings': {}}

# %%
import yaml

# %%
yaml_component = yaml.dump(s.netlist.model_dump(exclude_none=True))
print(yaml_component)
# Out:
# connections: {}
# info: {}
# instances:
#   s00:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s10:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s11:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s20:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s21:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s22:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s23:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s30:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s31:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s32:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s33:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s34:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s35:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s36:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s37:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s40:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s41:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s410:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s411:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s412:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s413:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s414:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s415:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s42:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s43:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s44:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s45:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s46:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s47:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s48:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
#   s49:
#     component: mmi1x2
#     settings:
#       cross_section: strip
#       gap_mmi: 0.25
#       length_mmi: 5.5
#       length_taper: 10.0
#       straight: straight
#       taper: taper
#       width_mmi: 2.5
#       width_taper: 1.0
# nets: []
# pdk: ''
# placements:
#   s00:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 0.0
#     y: -50.0
#   s10:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 100.0
#     y: -100.0
#   s11:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 100.0
#     y: 0.0
#   s20:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 200.0
#     y: -200.0
#   s21:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 200.0
#     y: -100.0
#   s22:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 200.0
#     y: 0.0
#   s23:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 200.0
#     y: 100.0
#   s30:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 300.0
#     y: -400.0
#   s31:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 300.0
#     y: -300.0
#   s32:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 300.0
#     y: -200.0
#   s33:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 300.0
#     y: -100.0
#   s34:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 300.0
#     y: 0.0
#   s35:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 300.0
#     y: 100.0
#   s36:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 300.0
#     y: 200.0
#   s37:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 300.0
#     y: 300.0
#   s40:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: -800.0
#   s41:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: -700.0
#   s410:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: 200.0
#   s411:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: 300.0
#   s412:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: 400.0
#   s413:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: 500.0
#   s414:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: 600.0
#   s415:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: 700.0
#   s42:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: -600.0
#   s43:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: -500.0
#   s44:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: -400.0
#   s45:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: -300.0
#   s46:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: -200.0
#   s47:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: -100.0
#   s48:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: 0.0
#   s49:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 400.0
#     y: 100.0
# ports: {}
# routes:
#   route_26:
#     links:
#       s00,o2: s10,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_27:
#     links:
#       s00,o3: s11,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_28:
#     links:
#       s10,o2: s20,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_29:
#     links:
#       s10,o3: s21,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_30:
#     links:
#       s11,o2: s22,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_31:
#     links:
#       s11,o3: s23,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_32:
#     links:
#       s20,o2: s30,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_33:
#     links:
#       s20,o3: s31,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_34:
#     links:
#       s21,o2: s32,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_35:
#     links:
#       s21,o3: s33,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_36:
#     links:
#       s22,o2: s34,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_37:
#     links:
#       s22,o3: s35,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_38:
#     links:
#       s23,o2: s36,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_39:
#     links:
#       s23,o3: s37,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_40:
#     links:
#       s30,o2: s40,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_41:
#     links:
#       s30,o3: s41,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_42:
#     links:
#       s31,o2: s42,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_43:
#     links:
#       s31,o3: s43,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_44:
#     links:
#       s32,o2: s44,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_45:
#     links:
#       s32,o3: s45,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_46:
#     links:
#       s33,o2: s46,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_47:
#     links:
#       s33,o3: s47,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_48:
#     links:
#       s34,o2: s48,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_49:
#     links:
#       s34,o3: s49,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_50:
#     links:
#       s35,o2: s410,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_51:
#     links:
#       s35,o3: s411,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_52:
#     links:
#       s36,o2: s412,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_53:
#     links:
#       s36,o3: s413,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_54:
#     links:
#       s37,o2: s414,o1
#     routing_strategy: route_bundle
#     settings: {}
#   route_55:
#     links:
#       s37,o3: s415,o1
#     routing_strategy: route_bundle
#     settings: {}
# warnings: {}

# %%
yaml.dump(s.netlist.model_dump(exclude_none=True), open("schematic.yaml", "w"))

# %% [markdown]
# ## Python routing

# %%
n = 2**3
splitter = gf.components.splitter_tree(noutputs=n, spacing=(50, 50))
dbr_array = gf.components.array(
    component=gf.c.dbr, rows=n, columns=1, row_pitch=1, column_pitch=3, centered=True
)
s = gt.Schematic()
s.add_instance("s", gt.Instance(component=splitter))
s.add_instance("dbr", gt.Instance(component=dbr_array))
s.add_placement("s", gt.Placement(x=0, y=0))
s.add_placement("dbr", gt.Placement(x=300, y=0))

for i in range(n):
    s.add_net(
        gt.Net(
            p1=f"s,o2_2_{i+1}",
            p2=f"dbr,o1_{i+1}_1",
            name="splitter_to_dbr",
            settings=dict(radius=5, sort_ports=True),
        )
    )

g = s.netlist
g
# Out:
# Netlist(pdk='', instances={'s': Instance(component='splitter_tree', settings={'coupler': 'mmi1x2', 'noutputs': 8, 'spacing': (50, 50), 'bend_s': 'bend_s', 'cross_section': 'strip'}, info={}, array=None), 'dbr': Instance(component='array', settings={'component': 'dbr', 'columns': 1, 'rows': 8, 'column_pitch': 3, 'row_pitch': 1, 'add_ports': True, 'centered': True, 'auto_rename_ports': False}, info={}, array=None)}, placements={'s': Placement(x=0.0, y=0.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False), 'dbr': Placement(x=300.0, y=0.0, xmin=None, ymin=None, xmax=None, ymax=None, dx=0, dy=0, port=None, rotation=0, mirror=False)}, connections={}, routes={'splitter_to_dbr': Bundle(links={'s,o2_2_1': 'dbr,o1_1_1', 's,o2_2_2': 'dbr,o1_2_1', 's,o2_2_3': 'dbr,o1_3_1', 's,o2_2_4': 'dbr,o1_4_1', 's,o2_2_5': 'dbr,o1_5_1', 's,o2_2_6': 'dbr,o1_6_1', 's,o2_2_7': 'dbr,o1_7_1', 's,o2_2_8': 'dbr,o1_8_1'}, settings={'radius': 5, 'sort_ports': True}, routing_strategy='route_bundle')}, name=None, info={}, ports={}, settings={}, nets=[], warnings={})

# %%
dbr_array.pprint_ports()
# Out:
# ┏━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ name   ┃ width ┃ orientation ┃ layer    ┃ center       ┃ port_type ┃
# ┡━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ o1_1_1 │ 0.5   │ 180.0       │ WG (1/0) │ (-1.6, -3.5) │ optical   │
# │ o1_2_1 │ 0.5   │ 180.0       │ WG (1/0) │ (-1.6, -2.5) │ optical   │
# │ o1_3_1 │ 0.5   │ 180.0       │ WG (1/0) │ (-1.6, -1.5) │ optical   │
# │ o1_4_1 │ 0.5   │ 180.0       │ WG (1/0) │ (-1.6, -0.5) │ optical   │
# │ o1_5_1 │ 0.5   │ 180.0       │ WG (1/0) │ (-1.6, 0.5)  │ optical   │
# │ o1_6_1 │ 0.5   │ 180.0       │ WG (1/0) │ (-1.6, 1.5)  │ optical   │
# │ o1_7_1 │ 0.5   │ 180.0       │ WG (1/0) │ (-1.6, 2.5)  │ optical   │
# │ o1_8_1 │ 0.5   │ 180.0       │ WG (1/0) │ (-1.6, 3.5)  │ optical   │
# └────────┴───────┴─────────────┴──────────┴──────────────┴───────────┘

# %%
splitter.pprint_ports()
# Out:
# ┏━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ name   ┃ width ┃ orientation ┃ layer    ┃ center         ┃ port_type ┃
# ┡━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ o1_0_0 │ 0.5   │ 180.0       │ WG (1/0) │ (-10.0, 0.0)   │ optical   │
# │ o2_2_1 │ 0.5   │ 0.0         │ WG (1/0) │ (165.5, -62.5) │ optical   │
# │ o2_2_2 │ 0.5   │ 0.0         │ WG (1/0) │ (165.5, -87.5) │ optical   │
# │ o2_2_3 │ 0.5   │ 0.0         │ WG (1/0) │ (165.5, -12.5) │ optical   │
# │ o2_2_4 │ 0.5   │ 0.0         │ WG (1/0) │ (165.5, -37.5) │ optical   │
# │ o2_2_5 │ 0.5   │ 0.0         │ WG (1/0) │ (165.5, 37.5)  │ optical   │
# │ o2_2_6 │ 0.5   │ 0.0         │ WG (1/0) │ (165.5, 12.5)  │ optical   │
# │ o2_2_7 │ 0.5   │ 0.0         │ WG (1/0) │ (165.5, 87.5)  │ optical   │
# │ o2_2_8 │ 0.5   │ 0.0         │ WG (1/0) │ (165.5, 62.5)  │ optical   │
# └────────┴───────┴─────────────┴──────────┴────────────────┴───────────┘

# %%
yaml.dump(s.netlist.model_dump(exclude_none=True), open("schematic.yaml", "w"))
yaml_component = yaml.dump(s.netlist.model_dump(exclude_none=True))
print(yaml_component)
# Out:
# connections: {}
# info: {}
# instances:
#   dbr:
#     component: array
#     settings:
#       add_ports: true
#       auto_rename_ports: false
#       centered: true
#       column_pitch: 3
#       columns: 1
#       component: dbr
#       row_pitch: 1
#       rows: 8
#   s:
#     component: splitter_tree
#     settings:
#       bend_s: bend_s
#       coupler: mmi1x2
#       cross_section: strip
#       noutputs: 8
#       spacing: !!python/tuple
#       - 50
#       - 50
# nets: []
# pdk: ''
# placements:
#   dbr:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 300.0
#     y: 0.0
#   s:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 0.0
#     y: 0.0
# ports: {}
# routes:
#   splitter_to_dbr:
#     links:
#       s,o2_2_1: dbr,o1_1_1
#       s,o2_2_2: dbr,o1_2_1
#       s,o2_2_3: dbr,o1_3_1
#       s,o2_2_4: dbr,o1_4_1
#       s,o2_2_5: dbr,o1_5_1
#       s,o2_2_6: dbr,o1_6_1
#       s,o2_2_7: dbr,o1_7_1
#       s,o2_2_8: dbr,o1_8_1
#     routing_strategy: route_bundle
#     settings:
#       radius: 5
#       sort_ports: true
# warnings: {}

# %%
import yaml

from gdsfactory.serialization import convert_tuples_to_lists

conf = s.netlist.model_dump(exclude_none=True)
conf = convert_tuples_to_lists(conf)
yaml_component = yaml.dump(conf)
print(yaml_component)
# Out:
# connections: {}
# info: {}
# instances:
#   dbr:
#     component: array
#     settings:
#       add_ports: true
#       auto_rename_ports: false
#       centered: true
#       column_pitch: 3
#       columns: 1
#       component: dbr
#       row_pitch: 1
#       rows: 8
#   s:
#     component: splitter_tree
#     settings:
#       bend_s: bend_s
#       coupler: mmi1x2
#       cross_section: strip
#       noutputs: 8
#       spacing:
#       - 50
#       - 50
# nets: []
# pdk: ''
# placements:
#   dbr:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 300.0
#     y: 0.0
#   s:
#     dx: 0
#     dy: 0
#     mirror: false
#     rotation: 0
#     x: 0.0
#     y: 0.0
# ports: {}
# routes:
#   splitter_to_dbr:
#     links:
#       s,o2_2_1: dbr,o1_1_1
#       s,o2_2_2: dbr,o1_2_1
#       s,o2_2_3: dbr,o1_3_1
#       s,o2_2_4: dbr,o1_4_1
#       s,o2_2_5: dbr,o1_5_1
#       s,o2_2_6: dbr,o1_6_1
#       s,o2_2_7: dbr,o1_7_1
#       s,o2_2_8: dbr,o1_8_1
#     routing_strategy: route_bundle
#     settings:
#       radius: 5
#       sort_ports: true
# warnings: {}

# %%
c = gf.read.from_yaml(yaml_component)
c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 c = gf.read.from_yaml(yaml_component)
#       2 c
#
# File ~/repos/pytools-lithography/pytools-litho-design/venv/lib/python3.12/site-packages/gdsfactory/read/from_yaml.py:798, in from_yaml(yaml_str, routing_strategies, label_instance_function, name)
#     796 refs = _get_references(c, pdk, net.instances)
#     797 _place_and_connect(g, refs, net.connections, net.placements)
# --> 798 c = _add_routes(c, refs, net.routes, routing_strategies)
#     799 c = _add_ports(c, refs, net.ports)
#     800 c = _add_labels(c, refs, label_instance_function)
#
# File ~/repos/pytools-lithography/pytools-litho-design/venv/lib/python3.12/site-packages/gdsfactory/read/from_yaml.py:986, in _add_routes(c, refs, routes, routing_strategies)
#     980     ports2 += _get_ports_from_portnames(refs, first2, middles2, last2)
#     981     route_names += [
#     982         f"{bundle_name}-{first1}{m1}{last1}-{first2}{m2}{last2}"
#     983         for m1, m2 in zip(middles1, middles2)
#     984     ]
# --> 986 routes_list = routing_strategy(  # type: ignore
#     987     c,
#     988     ports1=ports1,
#     989     ports2=ports2,
#     990     **bundle.settings,
#     991 )
#     992 routes_dict.update(dict(zip(route_names, routes_list)))
#     993 c.routes = routes_dict  # type: ignore
#
# File ~/repos/pytools-lithography/pytools-litho-design/venv/lib/python3.12/site-packages/gdsfactory/routing/route_bundle.py:186, in route_bundle(component, ports1, ports2, cross_section, layer, separation, bend, sort_ports, start_straight_length, end_straight_length, min_straight_taper, taper, port_type, collision_check_layers, on_collision, bboxes, allow_width_mismatch, radius, route_width, straight, auto_taper, waypoints, steps, start_angles, end_angles, router)
#     181         cross_section = partial(
#     182             gf.cross_section.cross_section, layer=layer, width=route_width
#     183         )
#     185     else:
# --> 186         raise ValueError(
#     187             f"Either {cross_section=} or {layer=} and {route_width=} must be provided"
#     188         )
#     190 c = component
#     191 ports1_ = list(ports1)
#
# ValueError: Either cross_section=None or layer=None and route_width=None must be provided
